# %% [markdown]
# # TTC Delay Data - Exploratory Data Analysis

# %% [markdown]
# ## 1. Load Data

# %% [markdown]
# ## 2. Understand the Dataset

# %% [markdown]
# ## 3. Missing Values

# %% [markdown]
# ## 4. Delay Distribution

# %% [markdown]
# ## 5. Temporal Patterns

# %% [markdown]
# ## 6. Route / Station Patterns

# %% [markdown]
# ## 7. Initial Observations
